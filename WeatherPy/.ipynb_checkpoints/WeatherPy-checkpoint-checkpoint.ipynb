# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500) (-80,-10)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500) (-70,-20)
lat_lngs = zip(lats, lngs) 

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 607

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1


# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

     # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"

    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    
#     # Run an API request for each of the cities
    try:
# #          # Parse the JSON and retrieve data
        response = requests.get(city_url)
        response = response.json()
        response
        city_weather = response['weather'][0]["main"]
        
#         # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response['coord']['lat']
        city_lng = response['coord']['lon']
        city_max_temp = response['main']['temp_max']
        city_humidity =response['main']['humidity']
        city_clouds = response['clouds']['all']
        city_wind = response['wind']['speed']
        city_country = response['sys']['country']
        

# #         # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
        
# #     # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# # Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")

print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | boali
# Processing Record 3 of Set 1 | oriximina
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | la paz
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | mulatupo
# Processing Record 9 of Set 1 | dunedin
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | lebu
# Processing Record 13 of Set 1 | lasa
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | bairiki
# Processing Record 16 of Set 1 | nemuro
# Processing Record 17 of Set 1 | khatanga
# Processing Record 18 of Set 1 | seoul
# Processing Record 19 of Set 1 | paamiut
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | nassau
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | flinders
# Processing Record 24 of Set 1 | kaitangata
# Processing Record 25 of Set 1 | barrow
# Processing Record 26 of Set 1 | thap than
# Processing Record 27 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 1 | chirongui
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | stornoway
# Processing Record 33 of Set 1 | ahipara
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | chokurdakh
# Processing Record 36 of Set 1 | praia
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | makinsk
# Processing Record 39 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | newport
# Processing Record 42 of Set 1 | muravlenko
# Processing Record 43 of Set 1 | yulara
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | saldanha
# Processing Record 47 of Set 1 | east london
# Processing Record 48 of Set 1 | husavik
# Processing Record 49 of Set 1 | kyaikto
# Processing Record 50 of Set 1 | dzilam gonzalez
# Processing Record 0 of Set 2 | gorontalo
# Processing Record 1 of Set 2 | sidi ali
# Processing Record 2 of Set 2 | tiksi
# Processing Record 3 of Set 2 | vila franca do campo
# Processing Record 4 of Set 2 | saint george
# Processing Record 5 of Set 2 | hermanus
# Processing Record 6 of Set 2 | hami
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 4 | taoudenni
# Processing Record 48 of Set 4 | linxia
# Processing Record 49 of Set 4 | alyangula
# Processing Record 0 of Set 5 | fort nelson
# Processing Record 1 of Set 5 | matara
# Processing Record 2 of Set 5 | nabire
# Processing Record 3 of Set 5 | galle
# Processing Record 4 of Set 5 | bambous virieux
# Processing Record 5 of Set 5 | norman wells
# Processing Record 6 of Set 5 | sinnamary
# Processing Record 7 of Set 5 | thompson
# Processing Record 8 of Set 5 | kununurra
# Processing Record 9 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 5 | uyemskiy
# Processing Record 11 of Set 5 | mount gambier
# Processing Record 12 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 13 of Set 5 | kristinehamn
# Processing Record 14 of Set 5 | marsaxlokk
# Processing Record 15 of Set 5 | kailua
# Processing Record 16 of Set 5 | amot
# Processing Record 17 of Set 5 | srednekolymsk
# Processing Record 18 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 5 | sakakah
# Processing Record 20 of Set 5 | beloha
# Processing Record 21 of Set 5 | mayo
# Processing Record 22 of Set 5 | stoke-on-trent
# Processing Record 23 of Set 5 | dovhe
# Processing Record 24 of Set 5 | kaeo
# Processing Record 25 of Set 5 | adre
# Processing Record 26 of Set 5 | port moresby
# Processing Record 27 of Set 5 | ribeira grande
# Processing Record 28 of Set 5 | we
# City not found. Skipping...
# Processing Record 29 of Set 5 | haines junction
# Processing Record 30 of Set 5 | vanavara
# Processing Record 31 of Set 5 | padang
# Processing Record 32 of Set 5 | anadyr
# Processing Record 33 of Set 5 | lavrentiya
# Processing Record 34 of Set 5 | chapais
# Processing Record 35 of Set 5 | pevek
# Processing Record 36 of Set 5 | kawalu
# Processing Record 37 of Set 5 | lasem
# Processing Record 38 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 5 | san patricio
# Processing Record 40 of Set 5 | mitu
# Processing Record 41 of Set 5 | nanortalik
# Processing Record 42 of Set 5 | goderich
# Processing Record 43 of Set 5 | obzor
# Processing Record 44 of Set 5 | lazarev
# Processing Record 45 of Set 5 | yar-sale
# Processing Record 46 of Set 5 | sobolevo
# Processing Record 47 of Set 5 | andra
# Processing Record 48 of Set 5 | vao
# Processing Record 49 of Set 5 | maceio
# Processing Record 0 of Set 6 | castelo do piaui
# Processing Record 1 of Set 6 | huty
# Processing Record 2 of Set 6 | lorengau
# Processing Record 3 of Set 6 | camocim
# Processing Record 4 of Set 6 | santa rosa
# Processing Record 5 of Set 6 | mount isa
# Processing Record 6 of Set 6 | novoorsk
# Processing Record 7 of Set 6 | palmetto
# Processing Record 8 of Set 6 | barcelos
# Processing Record 9 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 11 of Set 6 | lazaro cardenas
# Processing Record 12 of Set 6 | san carlos de bariloche
# Processing Record 13 of Set 6 | pauini
# Processing Record 14 of Set 6 | talnakh
# Processing Record 15 of Set 6 | umm lajj
# Processing Record 16 of Set 6 | yeppoon
# Processing Record 17 of Set 6 | faanui
# Processing Record 18 of Set 6 | margate
# Processing Record 19 of Set 6 | indianola
# Processing Record 20 of Set 6 | caxias
# Processing Record 21 of Set 6 | los llanos de aridane
# Processing Record 22 of Set 6 | chuy
# Processing Record 23 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 24 of Set 6 | sampit
# Processing Record 25 of Set 6 | synya
# Processing Record 26 of Set 6 | egvekinot
# Processing Record 27 of Set 6 | ortona
# Processing Record 28 of Set 6 | alofi
# Processing Record 29 of Set 6 | shimoda
# Processing Record 30 of Set 6 | alice springs
# Processing Record 31 of Set 6 | voh
# Processing Record 32 of Set 6 | peravurani
# Processing Record 33 of Set 6 | khandyga
# Processing Record 34 of Set 6 | ashland
# Processing Record 35 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 6 | bukama
# Processing Record 37 of Set 6 | pochutla
# Processing Record 38 of Set 6 | tuatapere
# Processing Record 39 of Set 6 | puertollano
# Processing Record 40 of Set 6 | zunyi
# Processing Record 41 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 42 of Set 6 | derzhavinsk
# Processing Record 43 of Set 6 | marsa matruh
# Processing Record 44 of Set 6 | garissa
# Processing Record 45 of Set 6 | beringovskiy
# Processing Record 46 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 6 | christchurch
# Processing Record 48 of Set 6 | andenes
# Processing Record 49 of Set 6 | kruisfontein
# Processing Record 0 of Set 7 | cabinda
# Processing Record 1 of Set 7 | devonport
# Processing Record 2 of Set 7 | ketchikan
# Processing Record 3 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 7 | richards bay
# Processing Record 5 of Set 7 | tessalit
# Processing Record 6 of Set 7 | safwah
# City not found. Skipping...
# Processing Record 7 of Set 7 | grindavik
# Processing Record 8 of Set 7 | todos santos
# Processing Record 9 of Set 7 | waipawa
# Processing Record 10 of Set 7 | severnyy-kospashskiy
# Processing Record 11 of Set 7 | upernavik
# Processing Record 12 of Set 7 | nago
# Processing Record 13 of Set 7 | tabou
# Processing Record 14 of Set 7 | dudinka
# Processing Record 15 of Set 7 | galesong
# Processing Record 16 of Set 7 | saskylakh
# Processing Record 17 of Set 7 | yellowknife
# Processing Record 18 of Set 7 | charters towers
# Processing Record 19 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 20 of Set 7 | pasighat
# Processing Record 21 of Set 7 | palmer
# Processing Record 22 of Set 7 | mango
# Processing Record 23 of Set 7 | vostok
# Processing Record 24 of Set 7 | leningradskiy
# Processing Record 25 of Set 7 | bethel
# Processing Record 26 of Set 7 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 27 of Set 7 | viedma
# Processing Record 28 of Set 7 | makriyialos
# City not found. Skipping...
# Processing Record 29 of Set 7 | aykhal
# Processing Record 30 of Set 7 | cordoba
# Processing Record 49 of Set 8 | sao raimundo nonato
# Processing Record 0 of Set 9 | tomaszow lubelski
# Processing Record 1 of Set 9 | port hedland
# Processing Record 2 of Set 9 | college
# Processing Record 3 of Set 9 | sabha
# Processing Record 4 of Set 9 | parrsboro
# Processing Record 5 of Set 9 | poso
# Processing Record 6 of Set 9 | fraserburgh
# Processing Record 7 of Set 9 | kirakira
# Processing Record 8 of Set 9 | sciacca
# Processing Record 9 of Set 9 | sao felix do xingu
# Processing Record 10 of Set 9 | san andres
# Processing Record 11 of Set 9 | portland
# Processing Record 12 of Set 9 | manbij
# Processing Record 13 of Set 9 | koslan
# Processing Record 14 of Set 9 | pandharpur
# Processing Record 15 of Set 9 | kardailovo
# Processing Record 16 of Set 9 | mosquera
# Processing Record 17 of Set 9 | camacha
# Processing Record 18 of Set 9 | taltal
# Processing Record 19 of Set 9 | gigmoto
# Processing Record 20 of Set 9 | opobo
# City not found. Skipping...
# Processing Record 21 of Set 9 | okha
# Processing Record 22 of Set 9 | le vauclin
# Processing Record 23 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 9 | calama
# Processing Record 25 of Set 9 | biak
# Processing Record 26 of Set 9 | mahebourg
# Processing Record 27 of Set 9 | airai
# Processing Record 28 of Set 9 | namibe
# Processing Record 29 of Set 9 | ixtapa
# Processing Record 30 of Set 9 | roswell
# Processing Record 31 of Set 9 | gurskoye
# City not found. Skipping...
# Processing Record 32 of Set 9 | zaykovo
# Processing Record 33 of Set 9 | rocha
# Processing Record 34 of Set 9 | evensk
# Processing Record 35 of Set 9 | el tarra
# Processing Record 36 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 9 | pljevlja
# Processing Record 38 of Set 9 | vestmanna
# Processing Record 39 of Set 9 | kumo
# Processing Record 40 of Set 9 | baikunthpur
# Processing Record 41 of Set 9 | srandakan
# Processing Record 42 of Set 9 | alakurtti
# Processing Record 43 of Set 9 | fethiye
# Processing Record 44 of Set 9 | lagoa
# Processing Record 45 of Set 9 | hay river
# Processing Record 46 of Set 9 | clovis
# Processing Record 47 of Set 9 | burica
# City not found. Skipping...
# Processing Record 48 of Set 9 | santiago
# Processing Record 49 of Set 9 | birjand
# Processing Record 0 of Set 10 | aylmer
# Processing Record 1 of Set 10 | douglas
# Processing Record 2 of Set 10 | bocas del toro
# Processing Record 3 of Set 10 | jutai
# Processing Record 4 of Set 10 | riposto
# Processing Record 5 of Set 10 | iracoubo
# Processing Record 6 of Set 10 | maldonado
# Processing Record 7 of Set 10 | high level
# Processing Record 8 of Set 10 | avera
# Processing Record 9 of Set 10 | tanda
# Processing Record 10 of Set 10 | dingle
# Processing Record 11 of Set 10 | aksu
# Processing Record 12 of Set 10 | tikrit
# Processing Record 13 of Set 10 | ornskoldsvik
# Processing Record 14 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 15 of Set 10 | west wendover
# Processing Record 16 of Set 10 | half moon bay
# Processing Record 17 of Set 10 | pervomayskiy
# Processing Record 18 of Set 10 | birin
# Processing Record 19 of Set 10 | kadoma
# Processing Record 20 of Set 10 | pangnirtung
# Processing Record 21 of Set 10 | lompoc
# Processing Record 22 of Set 10 | ponta delgada
# Processing Record 23 of Set 10 | atar
# Processing Record 24 of Set 10 | saint-jean-port-joli
# Processing Record 25 of Set 10 | challapata
# Processing Record 26 of Set 10 | kuching
# Processing Record 27 of Set 10 | emerald
# Processing Record 28 of Set 10 | puerto escondido
# Processing Record 29 of Set 10 | muskegon
# Processing Record 30 of Set 10 | channel-port aux basques
# Processing Record 31 of Set 10 | andarab
# City not found. Skipping...
# Processing Record 32 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 10 | fukue
# Processing Record 34 of Set 10 | parkersburg
# Processing Record 35 of Set 10 | henties bay
# Processing Record 36 of Set 10 | sinop
# Processing Record 37 of Set 10 | vanimo
# Processing Record 38 of Set 10 | nahrin
# Processing Record 39 of Set 10 | vitim
# Processing Record 40 of Set 10 | pecos
# Processing Record 41 of Set 10 | marabba
# Processing Record 42 of Set 10 | hvolsvollur
# Processing Record 43 of Set 10 | lephepe
# City not found. Skipping...
# Processing Record 44 of Set 10 | deputatskiy
# Processing Record 45 of Set 10 | suicheng
# Processing Record 46 of Set 10 | bubaque
# Processing Record 47 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 10 | ugoofaaru
# Processing Record 49 of Set 10 | seda
# Processing Record 0 of Set 11 | verkhniy fiagdon
# Processing Record 1 of Set 11 | port lincoln
# Processing Record 2 of Set 11 | castro
# Processing Record 3 of Set 11 | shache
# Processing Record 4 of Set 11 | tarko-sale
# Processing Record 5 of Set 11 | valdivia
# Processing Record 6 of Set 11 | marzuq
# Processing Record 7 of Set 11 | miri
# Processing Record 8 of Set 11 | praia da vitoria
# Processing Record 9 of Set 11 | san policarpo
# Processing Record 10 of Set 11 | hasaki
# Processing Record 11 of Set 11 | kalangala
# Processing Record 12 of Set 11 | guajara-mirim
# City not found. Skipping...
# Processing Record 13 of Set 11 | scarborough
# Processing Record 14 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 11 | holme
# Processing Record 16 of Set 11 | manzhouli
# Processing Record 17 of Set 11 | atambua
# Processing Record 18 of Set 11 | porbandar
# Processing Record 19 of Set 11 | itamaraca
# Processing Record 20 of Set 11 | jiaojiang
# Processing Record 21 of Set 11 | muroto
# Processing Record 22 of Set 11 | bundaberg
# Processing Record 23 of Set 11 | sorland
# Processing Record 24 of Set 11 | pasaje
# Processing Record 25 of Set 11 | mitsamiouli
# Processing Record 26 of Set 11 | severo-yeniseyskiy
# Processing Record 27 of Set 11 | comodoro rivadavia
# Processing Record 28 of Set 11 | edd
# Processing Record 29 of Set 11 | olafsvik
# Processing Record 30 of Set 11 | bondo
# Processing Record 31 of Set 11 | chokwe
# Processing Record 32 of Set 11 | agirish
# Processing Record 33 of Set 11 | murmashi
# Processing Record 34 of Set 11 | lokosovo
# Processing Record 35 of Set 11 | virtsu
# Processing Record 36 of Set 11 | pinawa
# Processing Record 37 of Set 11 | graaff-reinet
# Processing Record 38 of Set 11 | kumano
# Processing Record 39 of Set 11 | kangshan
# Processing Record 40 of Set 11 | san rafael
# Processing Record 41 of Set 11 | banda aceh
# Processing Record 42 of Set 11 | huejuquilla el alto
# Processing Record 43 of Set 11 | tecoanapa
# Processing Record 44 of Set 11 | cochrane
# Processing Record 45 of Set 11 | castro verde
# Processing Record 46 of Set 11 | wadi musa
# Processing Record 47 of Set 11 | mehamn
# Processing Record 48 of Set 11 | minot
# Processing Record 49 of Set 11 | boende
# Processing Record 0 of Set 12 | stephenville
# Processing Record 1 of Set 12 | bam
# Processing Record 2 of Set 12 | usinsk
# Processing Record 3 of Set 12 | guerrero negro
# Processing Record 4 of Set 12 | mangrol
# Processing Record 5 of Set 12 | sabang
# Processing Record 6 of Set 12 | luwuk
# Processing Record 7 of Set 12 | samarai
# Processing Record 8 of Set 12 | fort morgan
# Processing Record 9 of Set 12 | mandalgovi
# Processing Record 10 of Set 12 | touros
# Processing Record 11 of Set 12 | saint-joseph
# Processing Record 12 of Set 12 | port blair
# Processing Record 13 of Set 12 | san sebastian
# Processing Record 14 of Set 12 | tezu
# Processing Record 15 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 16 of Set 12 | koulamoutou
# Processing Record 17 of Set 12 | ovalle
# Processing Record 18 of Set 12 | kissidougou
# Processing Record 19 of Set 12 | dubbo
# Processing Record 20 of Set 12 | palaikastron
# Processing Record 21 of Set 12 | malabo
# Processing Record 22 of Set 12 | mogadouro
# Processing Record 23 of Set 12 | muriwai beach
# Processing Record 24 of Set 12 | preeceville
# Processing Record 25 of Set 12 | vardo
# Processing Record 26 of Set 12 | sherbakul
# Processing Record 27 of Set 12 | nouakchott
# Processing Record 28 of Set 12 | omboue
# Processing Record 29 of Set 12 | guia lopes da laguna
# Processing Record 30 of Set 12 | hasanabad
# Processing Record 31 of Set 12 | mirabad
# Processing Record 32 of Set 12 | buraydah
# Processing Record 33 of Set 12 | birao
# Processing Record 34 of Set 12 | varca
# Processing Record 35 of Set 12 | wufeng
# Processing Record 36 of Set 12 | brae
# Processing Record 37 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 38 of Set 12 | inirida
# Processing Record 39 of Set 12 | nishihara
# Processing Record 40 of Set 12 | kloulklubed
# Processing Record 41 of Set 12 | warri
# Processing Record 42 of Set 12 | havelock
# Processing Record 43 of Set 12 | tiznit
# Processing Record 44 of Set 12 | narasapur
# Processing Record 45 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 46 of Set 12 | innisfail
# Processing Record 47 of Set 12 | sulangan
# Processing Record 48 of Set 12 | alihe
# Processing Record 49 of Set 12 | teya
# Processing Record 0 of Set 13 | ibra
# Processing Record 1 of Set 13 | luderitz
# Processing Record 2 of Set 13 | paveh
# Processing Record 3 of Set 13 | nimaparha
# Processing Record 4 of Set 13 | kermanshah
# Processing Record 5 of Set 13 | portlethen
# Processing Record 6 of Set 13 | naze
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          554
# Lat           554
# Lng           554
# Max Temp      554
# Humidity      554
# Cloudiness    554
# Wind Speed    554
# Country       554
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       bluff -46.6000  168.3333     52.81        98          90       14.05
# 1       boali   4.8005   18.1275     85.41        57          72        1.36
# 2   oriximina  -1.7656  -55.8661     85.30        47         100        1.88
# 3  bredasdorp -34.5322   20.0403     72.43        33          99       17.16
# 4      la paz -16.5000  -68.1500     46.38        81          40        2.30
#
#   Country
# 0      NZ
# 1      CF
# 2      BR
# 3      ZA
# 4      BO

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             bluff -46.6000  168.3333     52.81        98          90
# 1             boali   4.8005   18.1275     85.41        57          72
# 2         oriximina  -1.7656  -55.8661     85.30        47         100
# 3        bredasdorp -34.5322   20.0403     72.43        33          99
# 4            la paz -16.5000  -68.1500     46.38        81          40
#
#          Wind Speed Country
# City_ID
# 0             14.05      NZ
# 1              1.36      CF
# 2              1.88      BR
# 3             17.16      ZA
# 4              2.30      BO

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Max Temp"]

plt.scatter(x_axis,y_axis)
plt.xlabel("Latitude")
plt.ylabel("Temperature")

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Humidity"]

plt.scatter(x_axis,y_axis,color="orange")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Cloudiness"]

plt.scatter(x_axis,y_axis,color="magenta")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Wind Speed"]

plt.scatter(x_axis,y_axis,color="green")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# (slope,intercept,rvalue,pvalue,stderr) = linregress(x_axis,y_axis)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)

northern_hemi_df = city_data_df.loc[(city_data_df["Lat"]>=0),:]
# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            boali   4.8005  18.1275     85.41        57          72
# 6         mulatupo   8.9492 -77.7652     75.38        92         100
# 8        jamestown  42.0970 -79.2353     28.71        61         100
# 9           albany  42.6001 -73.9662     32.41        81          93
# 11            lasa  46.6166  10.7002     54.01        64          92
#
#          Wind Speed Country
# City_ID
# 1              1.36      CF
# 6              4.47      PA
# 8             20.71      US
# 9              8.05      US
# 11             7.70      IT

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"]<0),:]

# Display sample data
southern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             bluff -46.6000  168.3333     52.81        98          90
# 2         oriximina  -1.7656  -55.8661     85.30        47         100
# 3        bredasdorp -34.5322   20.0403     72.43        33          99
# 4            la paz -16.5000  -68.1500     46.38        81          40
# 5            hobart -42.8794  147.3294     55.26        80          40
#
#          Wind Speed Country
# City_ID
# 0             14.05      NZ
# 2              1.88      BR
# 3             17.16      ZA
# 4              2.30      BO
# 5              8.05      AU

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Max Temp']

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_axis,y_axis)
regress_values = x_axis*slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.annotate(line_eq,(0,0),fontsize=12,color="red",fontweight="bold")
plt.show()

# %%
# Linear regression on Southern Hemisphere
x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Max Temp']

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_axis,y_axis)
regress_values = x_axis*slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_axis,y_axis,color="orange")
plt.plot(x_axis,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.annotate(line_eq,(-20,50),fontsize=12,color="blue",fontweight="bold")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:
#
# Temperature vs. Latitude relationship for the northern hemisphere displays a decrease in temperature as it approaches the poles.  For the southern hemisphere it shows the temperature is warmer as it approaches the equator.  If someone wants to live in cooler temperatures live in the north otherwise live south.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Humidity']

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_axis,y_axis)
regress_values = x_axis*slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq,(50,20),fontsize=12,color="red",fontweight="bold")
plt.show()

# %%
# Southern Hemisphere
x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Humidity']

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_axis,y_axis)
regress_values = x_axis*slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_axis,y_axis,color="orange")
plt.plot(x_axis,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq,(-20,20),fontsize=12,color="blue",fontweight="bold")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:
#
# Humidity vs. Latitude shows northern hemisphere is slightly more humid than the southern hemisphere as it approaches the poles.  The humidity for the southern hemisphere appears to increase slowly as it approaches the equator.  Based on the relationship with temperature and latitude displaying northern hemisphere being more cooler, the humidity may be higher in the north.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Cloudiness']

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_axis,y_axis)
regress_values = x_axis*slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(50,35),fontsize=12,color="red",fontweight="bold")
plt.show()

# %%
# Southern Hemisphere
x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Cloudiness']

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_axis,y_axis)
regress_values = x_axis*slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_axis,y_axis,color="orange")
plt.plot(x_axis,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(-55,5),fontsize=12,color="blue",fontweight="bold")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:
#
# Cloudiness vs. Latitude shows that cloudiness increases as you head north for both northern and southern hemisphere.  Around the equator there may be a drop in cloudiness.  However, q quick rise in cloudiness occurs after the equator heading into the northern hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df['Lat']
y_axis = northern_hemi_df['Wind Speed']

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_axis,y_axis)
regress_values = x_axis*slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line_eq,(10,30),fontsize=12,color="red",fontweight="bold")
plt.show()

# %%
# Southern Hemisphere
x_axis = southern_hemi_df['Lat']
y_axis = southern_hemi_df['Wind Speed']

(slope,intercept,rvalue,pvalue,stderr) = linregress(x_axis,y_axis)
regress_values = x_axis*slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_axis,y_axis,color="orange")
plt.plot(x_axis,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line_eq,(-50,20),fontsize=12,color="blue",fontweight="bold")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:
#
# Wind Speed vs. Latitude shows a significant decline in the southern hempisphere as it approaches 0 latitudes.  In the northern hemisphere wind speed has a slight incline, but positive latitudes do not have a siginificant impact on wind speed.
